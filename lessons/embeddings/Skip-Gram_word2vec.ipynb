# %% [markdown]
# # Skip-gram word2vec
#
# In this notebook, I'll lead you through using TensorFlow to implement the word2vec algorithm using the skip-gram architecture. By implementing this, you'll learn about embedding words for use in natural language processing. This will come in handy when dealing with things like machine translation.
#
# ## Readings
#
# Here are the resources I used to build this notebook. I suggest reading these either beforehand or while you're working on this material.
#
# * A really good [conceptual overview](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/) of word2vec from Chris McCormick
# * [First word2vec paper](https://arxiv.org/pdf/1301.3781.pdf) from Mikolov et al.
# * [NIPS paper](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf) with improvements for word2vec also from Mikolov et al.
# * An [implementation of word2vec](http://www.thushv.com/natural_language_processing/word2vec-part-1-nlp-with-deep-learning-with-tensorflow-skip-gram/) from Thushan Ganegedara
# * TensorFlow [word2vec tutorial](https://www.tensorflow.org/tutorials/word2vec)
#
# ## Word embeddings
#
# When you're dealing with words in text, you end up with tens of thousands of classes to predict, one for each word. Trying to one-hot encode these words is massively inefficient, you'll have one element set to 1 and the other 50,000 set to 0. The matrix multiplication going into the first hidden layer will have almost all of the resulting values be zero. This a huge waste of computation.
#
# ![one-hot encodings](assets/one_hot_encoding.png)
#
# To solve this problem and greatly increase the efficiency of our networks, we use what are called embeddings. Embeddings are just a fully connected layer like you've seen before. We call this layer the embedding layer and the weights are embedding weights. We skip the multiplication into the embedding layer by instead directly grabbing the hidden layer values from the weight matrix. We can do this because the multiplication of a one-hot encoded vector with a matrix returns the row of the matrix corresponding the index of the "on" input unit.
#
# ![lookup](assets/lookup_matrix.png)
#
# Instead of doing the matrix multiplication, we use the weight matrix as a lookup table. We encode the words as integers, for example "heart" is encoded as 958, "mind" as 18094. Then to get hidden layer values for "heart", you just take the 958th row of the embedding matrix. This process is called an **embedding lookup** and the number of hidden units is the **embedding dimension**.
#
# <img src='assets/tokenize_lookup.png' width=500>
#
# There is nothing magical going on here. The embedding lookup table is just a weight matrix. The embedding layer is just a hidden layer. The lookup is just a shortcut for the matrix multiplication. The lookup table is trained just like any weight matrix as well.
#
# Embeddings aren't only used for words of course. You can use them for any model where you have a massive number of classes. A particular type of model called **Word2Vec** uses the embedding layer to find vector representations of words that contain semantic meaning.

# %% [markdown]
# ## Word2Vec
#
# The word2vec algorithm finds much more efficient representations by finding vectors that represent the words. These vectors also contain semantic information about the words. Words that show up in similar contexts, such as "black", "white", and "red" will have vectors near each other. There are two architectures for implementing word2vec, CBOW (Continuous Bag-Of-Words) and Skip-gram.
#
# <img src="assets/word2vec_architectures.png" width="500">
#
# In this implementation, we'll be using the skip-gram architecture because it performs better than CBOW. Here, we pass in a word and try to predict the words surrounding it in the text. In this way, we can train the network to learn representations for words that show up in similar contexts.
#
# First up, importing packages.

# %%
import time

import numpy as np
import tensorflow as tf

import utils

# %% [markdown]
# Load the [text8 dataset](http://mattmahoney.net/dc/textdata.html), a file of cleaned up Wikipedia articles from Matt Mahoney. The next cell will download the data set to the `data` folder. Then you can extract it and delete the archive file to save storage space.

# %%
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import zipfile

dataset_folder_path = 'data'
dataset_filename = 'text8.zip'
dataset_name = 'Text8 Dataset'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(dataset_filename):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc=dataset_name) as pbar:
        urlretrieve(
            'http://mattmahoney.net/dc/text8.zip',
            dataset_filename,
            pbar.hook)

if not isdir(dataset_folder_path):
    with zipfile.ZipFile(dataset_filename) as zip_ref:
        zip_ref.extractall(dataset_folder_path)
        
with open('data/text8') as f:
    text = f.read()

# %% [markdown]
# ## Preprocessing
#
# Here I'm fixing up the text to make training easier. This comes from the `utils` module I wrote. The `preprocess` function coverts any punctuation into tokens, so a period is changed to ` <PERIOD> `. In this data set, there aren't any periods, but it will help in other NLP problems. I'm also removing all words that show up five or fewer times in the dataset. This will greatly reduce issues due to noise in the data and improve the quality of the vector representations. If you want to write your own functions for this stuff, go for it.

# %%
words = utils.preprocess(text)
print(words[:30])
# Out:
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english', 'revolution', 'and', 'the', 'sans', 'culottes', 'of', 'the', 'french', 'revolution', 'whilst']

# %%
print("Total words: {}".format(len(words)))
print("Unique words: {}".format(len(set(words))))
# Out:
# Total words: 16680599
# Unique words: 63641

# %% [markdown]
# And here I'm creating dictionaries to convert words to integers and backwards, integers to words. The integers are assigned in descending frequency order, so the most frequent word ("the") is given the integer 0 and the next most frequent is 1 and so on. The words are converted to integers and stored in the list `int_words`.

# %%
vocab_to_int, int_to_vocab = utils.create_lookup_tables(words)
int_words = [vocab_to_int[word] for word in words]

# %% [markdown]
# ## Subsampling
#
# Words that show up often such as "the", "of", and "for" don't provide much context to the nearby words. If we discard some of them, we can remove some of the noise from our data and in return get faster training and better representations. This process is called subsampling by Mikolov. For each word $w_i$ in the training set, we'll discard it with probability given by
#
# $$ P(w_i) = 1 - \sqrt{\frac{t}{f(w_i)}} $$
#
# where $t$ is a threshold parameter and $f(w_i)$ is the frequency of word $w_i$ in the total dataset.
#
# I'm going to leave this up to you as an exercise. This is more of a programming challenge, than about deep learning specifically. But, being able to prepare your data for your network is an important skill to have. Check out my solution to see how I did it.
#
# > **Exercise:** Implement subsampling for the words in `int_words`. That is, go through `int_words` and discard each word given the probablility $P(w_i)$ shown above. Note that $P(w_i)$ is the probability that a word is discarded. Assign the subsampled data to `train_words`.

# %%
## Your code here
from collections import Counter
import random


threshold = 1e-5
word_counts = Counter(int_words)
total_count = len(int_words)
freqs = {word: count/total_count for word, count in word_counts.items()}
p_drop = {word: 1 - np.sqrt(threshold/freqs[word]) for word in word_counts}
train_words = [word for word in int_words if random.random() < (1 - p_drop[word])]


len(train_words)
# Out:
# 4627751

# %% [markdown]
# ## Making batches

# %% [markdown]
# Now that our data is in good shape, we need to get it into the proper form to pass it into our network. With the skip-gram architecture, for each word in the text, we want to grab all the words in a window around that word, with size $C$.
#
# From [Mikolov et al.](https://arxiv.org/pdf/1301.3781.pdf):
#
# "Since the more distant words are usually less related to the current word than those close to it, we give less weight to the distant words by sampling less from those words in our training examples... If we choose $C = 5$, for each training word we will select randomly a number $R$ in range $< 1; C >$, and then use $R$ words from history and $R$ words from the future of the current word as correct labels."
#
# > **Exercise:** Implement a function `get_target` that receives a list of words, an index, and a window size, then returns a list of words in the window around the index. Make sure to use the algorithm described above, where you choose a random number of words from the window.

# %%
import random

def get_target(words, idx, window_size=5):
    ''' Get a list of words in a window around an index. '''
    
    random_window = random.randrange(1, window_size + 1)
    
    
    start = max(idx - random_window, 0)
#     print(start)
    end = min(idx + random_window + 1, len(words))
#     print(end)
    
    left = words[start:idx]
#     print(left)
    right = words[idx + 1: end]
#     print(right)
    
#     print(words[start:end])
    
    return list(set(left + right))

get_target(train_words, 2)
# Out:
# [58112, 10571, 27349, 150, 15067]

# %% [markdown]
# Here's a function that returns batches for our network. The idea is that it grabs `batch_size` words from a words list. Then for each of those words, it gets the target words in the window. I haven't found a way to pass in a random number of target words and get it to work with the architecture, so I make one row per input-target pair. This is a generator function by the way, helps save memory.

# %%
def get_batches(words, batch_size, window_size=5):
    ''' Create a generator of word batches as a tuple (inputs, targets) '''
    
    n_batches = len(words)//batch_size
    
    # only full batches
    words = words[:n_batches*batch_size]
    
    for idx in range(0, len(words), batch_size):
        x, y = [], []
        batch = words[idx:idx+batch_size]
        for ii in range(len(batch)):
            batch_x = batch[ii]
            batch_y = get_target(batch, ii, window_size)
            y.extend(batch_y)
            x.extend([batch_x]*len(batch_y))
        yield x, y

# %% [markdown]
# ## Building the graph
#
# From [Chris McCormick's blog](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/), we can see the general structure of our network.
# ![embedding_network](./assets/skip_gram_net_arch.png)
#
# The input words are passed in as integers. This will go into a hidden layer of linear units, then into a softmax layer. We'll use the softmax layer to make a prediction like normal.
#
# The idea here is to train the hidden layer weight matrix to find efficient representations for our words. We can discard the softmax layer becuase we don't really care about making predictions with this network. We just want the embedding matrix so we can use it in other networks we build from the dataset.
#
# I'm going to have you build the graph in stages now. First off, creating the `inputs` and `labels` placeholders like normal.
#
# > **Exercise:** Assign `inputs` and `labels` using `tf.placeholder`. We're going to be passing in integers, so set the data types to `tf.int32`. The batches we're passing in will have varying sizes, so set the batch sizes to [`None`]. To make things work later, you'll need to set the second dimension of `labels` to `None` or `1`.

# %%
train_graph = tf.Graph()
with train_graph.as_default():
    inputs = tf.placeholder(tf.int32, [None], name="inputs")
    labels = tf.placeholder(tf.int32, [None, None], name="labels")

# %% [markdown]
# ## Embedding

# %% [markdown]
# The embedding matrix has a size of the number of words by the number of units in the hidden layer. So, if you have 10,000 words and 300 hidden units, the matrix will have size $10,000 \times 300$. Remember that we're using tokenized data for our inputs, usually as integers, where the number of tokens is the number of words in our vocabulary.
#
#
# > **Exercise:** Tensorflow provides a convenient function [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) that does this lookup for us. You pass in the embedding matrix and a tensor of integers, then it returns rows in the matrix corresponding to those integers. Below, set the number of embedding features you'll use (200 is a good start), create the embedding matrix variable, and use `tf.nn.embedding_lookup` to get the embedding tensors. For the embedding matrix, I suggest you initialize it with a uniform random numbers between -1 and 1 using [tf.random_uniform](https://www.tensorflow.org/api_docs/python/tf/random_uniform).

# %%
n_vocab = len(int_to_vocab)
n_embedding = 200 # Number of embedding features 
with train_graph.as_default():
    embedding = tf.Variable(tf.random_uniform((n_vocab, n_embedding), -1, 1))
    embed = tf.nn.embedding_lookup(embedding, inputs)

# %% [markdown]
# ## Negative sampling

# %% [markdown]
# For every example we give the network, we train it using the output from the softmax layer. That means for each input, we're making very small changes to millions of weights even though we only have one true example. This makes training the network very inefficient. We can approximate the loss from the softmax layer by only updating a small subset of all the weights at once. We'll update the weights for the correct label, but only a small number of incorrect labels. This is called ["negative sampling"](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf). Tensorflow has a convenient function to do this, [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss).
#
# > **Exercise:** Below, create weights and biases for the softmax layer. Then, use [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss) to calculate the loss. Be sure to read the documentation to figure out how it works.

# %%
# Number of negative labels to sample
n_sampled = 100
with train_graph.as_default():
    softmax_w = tf.Variable(tf.truncated_normal((n_vocab, n_embedding), stddev=0.1))
    softmax_b = tf.Variable(tf.zeros(n_vocab))
    
    loss = tf.nn.sampled_softmax_loss(softmax_w, softmax_b, 
                                      labels, embed,
                                      n_sampled, n_vocab)
    
    cost = tf.reduce_mean(loss)
    optimizer = tf.train.AdamOptimizer().minimize(cost)
# Out:
# WARNING:tensorflow:From /home/miquel/anaconda3/envs/tensorflow/lib/python3.6/site-packages/tensorflow/python/ops/nn_impl.py:1344: softmax_cross_entropy_with_logits (from tensorflow.python.ops.nn_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
#
# Future major versions of TensorFlow will allow gradients to flow
# into the labels input on backprop by default.
#
# See @{tf.nn.softmax_cross_entropy_with_logits_v2}.

# %% [markdown]
# ## Validation
#
# This code is from Thushan Ganegedara's implementation. Here we're going to choose a few common words and few uncommon words. Then, we'll print out the closest words to them. It's a nice way to check that our embedding table is grouping together words with similar semantic meanings.

# %%
with train_graph.as_default():
    ## From Thushan Ganegedara's implementation
    valid_size = 16 # Random set of words to evaluate similarity on.
    valid_window = 100
    # pick 8 samples from (0,100) and (1000,1100) each ranges. lower id implies more frequent 
    valid_examples = np.array(random.sample(range(valid_window), valid_size//2))
    valid_examples = np.append(valid_examples, 
                               random.sample(range(1000,1000+valid_window), valid_size//2))

    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embedding), 1, keep_dims=True))
    normalized_embedding = embedding / norm
    valid_embedding = tf.nn.embedding_lookup(normalized_embedding, valid_dataset)
    similarity = tf.matmul(valid_embedding, tf.transpose(normalized_embedding))
# Out:
# WARNING:tensorflow:From <ipython-input-12-2aa168c49a56>:13: calling reduce_sum (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead

# %%
# If the checkpoints directory doesn't exist:
# !mkdir checkpoints
# Out:
# mkdir: cannot create directory ‘checkpoints’: File exists

# %% [markdown]
# ## Training
#
# Below is the code to train the network. Every 100 batches it reports the training loss. Every 1000 batches, it'll print out the validation words.

# %%
epochs = 10
batch_size = 1000
window_size = 10

with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    iteration = 1
    loss = 0
    sess.run(tf.global_variables_initializer())

    for e in range(1, epochs+1):
        batches = get_batches(train_words, batch_size, window_size)
        start = time.time()
        for x, y in batches:
            
            feed = {inputs: x,
                    labels: np.array(y)[:, None]}
            train_loss, _ = sess.run([cost, optimizer], feed_dict=feed)
            
            loss += train_loss
            
            if iteration % 100 == 0: 
                end = time.time()
                print("Epoch {}/{}".format(e, epochs),
                      "Iteration: {}".format(iteration),
                      "Avg. Training loss: {:.4f}".format(loss/100),
                      "{:.4f} sec/batch".format((end-start)/100))
                loss = 0
                start = time.time()
            
            if iteration % 1000 == 0:
                ## From Thushan Ganegedara's implementation
                # note that this is expensive (~20% slowdown if computed every 500 steps)
                sim = similarity.eval()
                for i in range(valid_size):
                    valid_word = int_to_vocab[valid_examples[i]]
                    top_k = 8 # number of nearest neighbors
                    nearest = (-sim[i, :]).argsort()[1:top_k+1]
                    log = 'Nearest to %s:' % valid_word
                    for k in range(top_k):
                        close_word = int_to_vocab[nearest[k]]
                        log = '%s %s,' % (log, close_word)
                    print(log)
            
            iteration += 1
    save_path = saver.save(sess, "checkpoints/text8.ckpt")
    embed_mat = sess.run(normalized_embedding)
# Out:
# Epoch 1/10 Iteration: 100 Avg. Training loss: 5.6898 0.0531 sec/batch
# Epoch 1/10 Iteration: 200 Avg. Training loss: 5.6040 0.0226 sec/batch
# Epoch 1/10 Iteration: 300 Avg. Training loss: 5.5122 0.0226 sec/batch
# Epoch 1/10 Iteration: 400 Avg. Training loss: 5.6150 0.0225 sec/batch
# Epoch 1/10 Iteration: 500 Avg. Training loss: 5.4874 0.0225 sec/batch
# Epoch 1/10 Iteration: 600 Avg. Training loss: 5.4929 0.0225 sec/batch
# Epoch 1/10 Iteration: 700 Avg. Training loss: 5.5793 0.0226 sec/batch
# Epoch 1/10 Iteration: 800 Avg. Training loss: 5.5394 0.0225 sec/batch
# Epoch 1/10 Iteration: 900 Avg. Training loss: 5.4799 0.0225 sec/batch
# Epoch 1/10 Iteration: 1000 Avg. Training loss: 5.4158 0.0226 sec/batch
# Nearest to his: anglorum, neighbourhoods, appalled, leverage, preoccupation, tutti, msil, walker,
# Nearest to where: seconda, nepalese, shipped, stow, capitol, imperial, embolism, tried,
# Nearest to to: retainer, tack, sketched, concerning, confesses, furor, gyeonggi, jomo,
# Nearest to after: emmylou, cumbric, residents, loc, other, stratified, montauban, jabbar,
# Nearest to so: foobar, oic, mirrored, theodicy, fasttrack, galego, books, fairhair,
# Nearest to of: diazonium, squarely, wales, enables, crank, deteriorated, kerensky, unincorporated,
# Nearest to that: quintessential, sanfl, vistas, calwell, nicobar, bomb, baptiste, mss,
# Nearest to all: leppard, kraftwerk, condom, losers, viipuri, watercolor, ballpoint, lexicographic,
# Nearest to discovered: boss, platonist, kickapoo, cemented, nasional, penni, kyat, irix,
# Nearest to placed: kaveri, johansen, delphic, placekicker, anaesthetic, puddle, songhai, remain,
# Nearest to hit: squealer, yzerman, intermingled, hailie, solidifies, algiris, donnelly, hara,
# Nearest to arts: alcoholics, charging, refrains, henrique, retardation, optimised, minimum, symmetries,
# Nearest to cost: valo, nodens, xue, lilla, reorganised, atheism, filename, tisha,
# Nearest to professional: tatsam, vase, mombasa, dynamically, irving, brand, coincidental, mep,
# Nearest to freedom: uncontroversial, coinages, ashore, codepoint, heads, meditative, fauvism, messengers,
# Nearest to smith: owl, modular, ransoming, developer, thinly, eia, opening, oppidum,
# Epoch 1/10 Iteration: 1100 Avg. Training loss: 5.5051 0.0241 sec/batch
# Epoch 1/10 Iteration: 1200 Avg. Training loss: 5.3741 0.0226 sec/batch
# Epoch 1/10 Iteration: 1300 Avg. Training loss: 5.3183 0.0225 sec/batch
# Epoch 1/10 Iteration: 1400 Avg. Training loss: 5.2290 0.0225 sec/batch
# Epoch 1/10 Iteration: 1500 Avg. Training loss: 5.1705 0.0225 sec/batch
# Epoch 1/10 Iteration: 1600 Avg. Training loss: 5.1584 0.0225 sec/batch
# Epoch 1/10 Iteration: 1700 Avg. Training loss: 5.1248 0.0225 sec/batch
# Epoch 1/10 Iteration: 1800 Avg. Training loss: 5.0555 0.0226 sec/batch
# Epoch 1/10 Iteration: 1900 Avg. Training loss: 4.9880 0.0225 sec/batch
# Epoch 1/10 Iteration: 2000 Avg. Training loss: 4.9739 0.0226 sec/batch
# Nearest to his: neighbourhoods, walker, leverage, anglorum, infant, appalled, respected, modeled,
# Nearest to where: imperial, objects, tried, storing, nepalese, seconda, capitol, staying,
# Nearest to to: reason, off, concerning, offices, sketched, tack, confesses, jomo,
# Nearest to after: other, residents, declaring, loc, cumbric, superintendent, emmylou, maglev,
# Nearest to so: said, mirrored, books, galego, greater, foobar, bend, about,
# Nearest to of: wales, squarely, diazonium, anniversary, kenneth, willing, legendary, some,
# Nearest to that: quintessential, enacted, not, bomb, oriented, pit, out, registered,
# Nearest to all: leppard, kraftwerk, losers, unacceptable, legendary, xinjiang, condom, viipuri,
# Nearest to discovered: boss, platonist, make, when, cemented, aspects, kickapoo, tackled,
# Nearest to placed: remain, kaveri, johansen, delphic, expression, placekicker, derivation, eventually,
# Nearest to hit: yzerman, islands, squealer, coral, being, incremented, rough, hara,
# Nearest to arts: charging, raising, minimum, optimised, refrains, bouncing, regions, exceptions,
# Nearest to cost: vicugna, variety, inimitable, atheism, valo, nodens, countless, filename,
# Nearest to professional: tatsam, dynamically, vase, underwent, mombasa, brand, irving, intervention,
# Nearest to freedom: uncontroversial, coinages, heads, outside, simplicity, round, codepoint, ashore,
# Nearest to smith: owl, modular, opening, developer, ransoming, thinly, correctly, prefer,
# Epoch 1/10 Iteration: 2100 Avg. Training loss: 4.9428 0.0232 sec/batch
# Epoch 1/10 Iteration: 2200 Avg. Training loss: 4.8971 0.0225 sec/batch
# Epoch 1/10 Iteration: 2300 Avg. Training loss: 4.8874 0.0225 sec/batch
# Epoch 1/10 Iteration: 2400 Avg. Training loss: 4.8564 0.0226 sec/batch
# Epoch 1/10 Iteration: 2500 Avg. Training loss: 4.7799 0.0225 sec/batch
# Epoch 1/10 Iteration: 2600 Avg. Training loss: 4.8238 0.0225 sec/batch
# Epoch 1/10 Iteration: 2700 Avg. Training loss: 4.8006 0.0226 sec/batch
# Epoch 1/10 Iteration: 2800 Avg. Training loss: 4.7875 0.0226 sec/batch
# Epoch 1/10 Iteration: 2900 Avg. Training loss: 4.7906 0.0226 sec/batch
# Epoch 1/10 Iteration: 3000 Avg. Training loss: 4.7687 0.0226 sec/batch
# Nearest to his: walker, leverage, anglorum, neighbourhoods, daughter, appalled, giedi, preoccupation,
# Nearest to where: arctic, tried, storing, seconda, objects, interruptions, nepalese, stow,
# Nearest to to: reason, sketched, offices, off, retainer, concerning, requisite, tack,
# Nearest to after: other, residents, loc, cumbric, stratified, declaring, maglev, troy,
# Nearest to so: mirrored, said, books, foobar, galego, snakes, bend, farting,
# Nearest to of: diazonium, wales, squarely, willing, kenneth, resumed, decree, crank,
# Nearest to that: quintessential, not, enacted, premiere, bomb, oriented, registered, believed,
# Nearest to all: losers, kraftwerk, leppard, condom, viipuri, unacceptable, ling, simulating,
# Nearest to discovered: boss, platonist, cemented, tackled, rourke, kickapoo, when, make,
# Nearest to placed: johansen, remain, kaveri, delphic, leipzig, placekicker, fishes, downward,
# Nearest to hit: yzerman, islands, hara, squealer, vertices, solidifies, quito, landings,
# Nearest to arts: charging, raising, minimum, refrains, regions, bouncing, symmetries, optional,
# Nearest to cost: vicugna, variety, inimitable, filename, valo, countless, pharmacology, consume,
# Nearest to professional: vase, tatsam, dynamically, laying, irving, underwent, brand, gift,
# Nearest to freedom: coinages, heads, uncontroversial, codepoint, ashore, publicly, simplicity, outside,
# Nearest to smith: modular, owl, opening, thinly, ransoming, developer, underworld, eia,
# Epoch 1/10 Iteration: 3100 Avg. Training loss: 4.7734 0.0232 sec/batch
# Epoch 1/10 Iteration: 3200 Avg. Training loss: 4.7510 0.0226 sec/batch
# Epoch 1/10 Iteration: 3300 Avg. Training loss: 4.7480 0.0226 sec/batch
# Epoch 1/10 Iteration: 3400 Avg. Training loss: 4.7074 0.0225 sec/batch
# Epoch 1/10 Iteration: 3500 Avg. Training loss: 4.7399 0.0227 sec/batch
# Epoch 1/10 Iteration: 3600 Avg. Training loss: 4.7223 0.0226 sec/batch
# Epoch 1/10 Iteration: 3700 Avg. Training loss: 4.7118 0.0226 sec/batch
# Epoch 1/10 Iteration: 3800 Avg. Training loss: 4.7235 0.0225 sec/batch
# Epoch 1/10 Iteration: 3900 Avg. Training loss: 4.7180 0.0225 sec/batch
# Epoch 1/10 Iteration: 4000 Avg. Training loss: 4.6776 0.0226 sec/batch
# Nearest to his: daughter, walker, preoccupation, boiler, anglorum, giedi, parishioners, modeled,
# Nearest to where: arctic, interruptions, seconda, storing, tried, num, objects, stow,
# Nearest to to: jomo, retainer, reason, sketched, requisite, offices, tack, rows,
# Nearest to after: loc, other, residents, cumbric, recounted, republican, declaring, grasshopper,
# Nearest to so: mirrored, said, foobar, orthogonality, books, snakes, galego, farting,
# Nearest to of: squarely, diazonium, decree, wales, retainers, kenneth, crank, resumed,
# Nearest to that: quintessential, not, oriented, enacted, out, premiere, believed, mss,
# Nearest to all: kraftwerk, losers, leppard, ling, viipuri, condom, unacceptable, espy,
# Nearest to discovered: boss, platonist, cemented, rourke, tackled, kickapoo, lumbar, proximate,
# Nearest to placed: remain, kaveri, johansen, delphic, leipzig, puddle, anaesthetic, downward,
# Nearest to hit: yzerman, hara, squealer, islands, vertices, landings, algiris, purim,
# Nearest to arts: raising, charging, refrains, symmetries, bouncing, patriarchates, intifada, optional,
# Nearest to cost: variety, valo, filename, vicugna, inimitable, attenuated, nodens, atheism,
# Nearest to professional: vase, tatsam, dynamically, laying, irving, brand, gift, shocked,
# Nearest to freedom: uncontroversial, coinages, heads, ashore, codepoint, publicly, messengers, serbs,
# Nearest to smith: owl, modular, opening, thinly, eia, ransoming, steed, anguished,
# Epoch 1/10 Iteration: 4100 Avg. Training loss: 4.6755 0.0232 sec/batch
# Epoch 1/10 Iteration: 4200 Avg. Training loss: 4.6648 0.0226 sec/batch
# Epoch 1/10 Iteration: 4300 Avg. Training loss: 4.6210 0.0226 sec/batch
# Epoch 1/10 Iteration: 4400 Avg. Training loss: 4.6341 0.0226 sec/batch
# Epoch 1/10 Iteration: 4500 Avg. Training loss: 4.6155 0.0226 sec/batch
# Epoch 1/10 Iteration: 4600 Avg. Training loss: 4.6165 0.0226 sec/batch
# Epoch 2/10 Iteration: 4700 Avg. Training loss: 4.5857 0.0165 sec/batch
# Epoch 2/10 Iteration: 4800 Avg. Training loss: 4.5659 0.0226 sec/batch
# Epoch 2/10 Iteration: 4900 Avg. Training loss: 4.4942 0.0226 sec/batch
# Epoch 2/10 Iteration: 5000 Avg. Training loss: 4.5254 0.0226 sec/batch
# Nearest to his: daughter, wife, walker, boiler, parishioners, preoccupation, appalled, giedi,
# Nearest to where: arctic, seconda, interruptions, tried, objects, ringed, storing, stow,
# Nearest to to: marbles, jomo, sketched, tack, requisite, retainer, kal, offices,
# Nearest to after: loc, residents, cumbric, declaring, lusitanian, other, cyberpunk, depot,
# Nearest to so: said, orthogonality, foobar, odysseus, mirrored, farting, galego, bend,
# Nearest to of: squarely, retainers, decree, diazonium, wales, handmaid, kerensky, crank,
# Nearest to that: not, believed, quintessential, out, employee, mss, oriented, luminous,
# Nearest to all: kraftwerk, losers, ling, condom, viipuri, lexicographic, leppard, unacceptable,
# Nearest to discovered: boss, platonist, rourke, kickapoo, cemented, lumbar, tackled, mesons,
# Nearest to placed: delphic, remain, johansen, kaveri, puddle, bodies, fishes, leipzig,
# Nearest to hit: hara, yzerman, squealer, tumour, donnelly, algiris, vertices, landings,
# Nearest to arts: raising, symmetries, refrains, rivaling, charging, patriarchates, tra, optional,
# Nearest to cost: filename, variety, valo, inimitable, vicugna, excel, attenuated, lilla,
# Nearest to professional: vase, tatsam, irving, laying, dynamically, shocked, gift, brand,
# Nearest to freedom: heads, uncontroversial, coinages, publicly, codepoint, ashore, communism, messengers,
# Nearest to smith: owl, modular, thinly, opening, eia, anguished, vance, rothbard,
# Epoch 2/10 Iteration: 5100 Avg. Training loss: 4.4831 0.0233 sec/batch
# Epoch 2/10 Iteration: 5200 Avg. Training loss: 4.4937 0.0225 sec/batch
# Epoch 2/10 Iteration: 5300 Avg. Training loss: 4.4602 0.0225 sec/batch
# Epoch 2/10 Iteration: 5400 Avg. Training loss: 4.5340 0.0225 sec/batch
# Epoch 2/10 Iteration: 5500 Avg. Training loss: 4.4708 0.0225 sec/batch
# Epoch 2/10 Iteration: 5600 Avg. Training loss: 4.4819 0.0225 sec/batch
# Epoch 2/10 Iteration: 5700 Avg. Training loss: 4.4416 0.0226 sec/batch
# Epoch 2/10 Iteration: 5800 Avg. Training loss: 4.3982 0.0225 sec/batch
# Epoch 2/10 Iteration: 5900 Avg. Training loss: 4.4371 0.0225 sec/batch
# Epoch 2/10 Iteration: 6000 Avg. Training loss: 4.4335 0.0225 sec/batch
# Nearest to his: daughter, wife, tutti, worship, anglorum, walker, appalled, dogma,
# Nearest to where: seconda, arctic, interruptions, objects, ringed, embolism, nepalese, storing,
# Nearest to to: marbles, requisite, reason, offices, kal, sketched, tack, jomo,
# Nearest to after: loc, declaring, residents, emmylou, lusitanian, grasshopper, fled, astute,
# Nearest to so: said, orthogonality, foobar, odysseus, mirrored, farting, galego, bend,
# Nearest to of: squarely, decree, retainers, diazonium, mantis, massif, handmaid, wales,
# Nearest to that: not, believed, mss, quintessential, luminous, emotionally, philosophical, reducible,
# Nearest to all: kraftwerk, condom, shingon, lexicographic, possible, losers, sectarianism, ling,
# Nearest to discovered: boss, lumbar, rourke, platonist, tackled, mesons, kickapoo, barrage,
# Nearest to placed: delphic, remain, kaveri, puddle, fishes, johansen, untouchables, placekicker,
# Nearest to hit: hara, yzerman, algiris, defensive, donnelly, squealer, srinivasa, band,
# Nearest to arts: rivaling, refrains, raising, alcoholics, tra, patriarchates, symmetries, henrique,
# Nearest to cost: filename, variety, excel, valo, vicugna, cuboctahedra, attenuated, inimitable,
# Nearest to professional: vase, irving, laying, tatsam, shocked, dynamically, brand, gift,
# Nearest to freedom: heads, coinages, publicly, uncontroversial, communism, ashore, codepoint, messengers,
# Nearest to smith: owl, opening, modular, thinly, anguished, vance, eia, rothbard,
# Epoch 2/10 Iteration: 6100 Avg. Training loss: 4.4556 0.0232 sec/batch
# Epoch 2/10 Iteration: 6200 Avg. Training loss: 4.4023 0.0226 sec/batch
# Epoch 2/10 Iteration: 6300 Avg. Training loss: 4.4370 0.0226 sec/batch
# Epoch 2/10 Iteration: 6400 Avg. Training loss: 4.3967 0.0225 sec/batch
# Epoch 2/10 Iteration: 6500 Avg. Training loss: 4.3923 0.0225 sec/batch
# Epoch 2/10 Iteration: 6600 Avg. Training loss: 4.4455 0.0226 sec/batch
# Epoch 2/10 Iteration: 6700 Avg. Training loss: 4.3678 0.0226 sec/batch
# Epoch 2/10 Iteration: 6800 Avg. Training loss: 4.3719 0.0225 sec/batch
# Epoch 2/10 Iteration: 6900 Avg. Training loss: 4.4122 0.0225 sec/batch
# Epoch 2/10 Iteration: 7000 Avg. Training loss: 4.3728 0.0226 sec/batch
# Nearest to his: daughter, wife, tutti, walker, giedi, worship, anglorum, appalled,
# Nearest to where: seconda, interruptions, arctic, objects, ringed, slacks, jacks, tried,
# Nearest to to: marbles, sketched, requisite, offices, northumbrian, reason, tack, jomo,
# Nearest to after: loc, declaring, emmylou, depot, astute, lusitanian, grasshopper, residents,
# Nearest to so: said, orthogonality, foobar, odysseus, farting, snakes, cornhuskers, chani,
# Nearest to of: handmaid, decree, squarely, retainers, kerensky, unincorporated, protestant, wales,
# Nearest to that: not, believed, mss, quintessential, philosophical, prove, deadlocked, calwell,
# Nearest to all: lexicographic, kraftwerk, shingon, condom, sectarianism, darwinian, possible, espy,
# Nearest to discovered: boss, lumbar, mesons, phenols, tackled, arborway, marbles, barrage,
# Nearest to placed: delphic, remain, kaveri, puddle, fishes, bodies, johansen, placekicker,
# Nearest to hit: yzerman, hara, defensive, algiris, band, paddling, tumour, squealer,
# Nearest to arts: rivaling, refrains, raising, tra, attestation, patriarchates, alcoholics, symmetries,
# Nearest to cost: filename, variety, excel, valo, cuboctahedra, attenuated, vicugna, curling,
# Nearest to professional: vase, irving, laying, brand, dynamically, shocked, tatsam, parapet,
# Nearest to freedom: heads, publicly, communism, coinages, codepoint, uncontroversial, messengers, freedoms,
# Nearest to smith: owl, modular, opening, thinly, anguished, vance, steed, dontrelle,
# Epoch 2/10 Iteration: 7100 Avg. Training loss: 4.3632 0.0232 sec/batch
# Epoch 2/10 Iteration: 7200 Avg. Training loss: 4.3924 0.0226 sec/batch
# Epoch 2/10 Iteration: 7300 Avg. Training loss: 4.3356 0.0226 sec/batch
# Epoch 2/10 Iteration: 7400 Avg. Training loss: 4.3727 0.0225 sec/batch
# Epoch 2/10 Iteration: 7500 Avg. Training loss: 4.4190 0.0225 sec/batch
# Epoch 2/10 Iteration: 7600 Avg. Training loss: 4.3714 0.0226 sec/batch
# Epoch 2/10 Iteration: 7700 Avg. Training loss: 4.3907 0.0226 sec/batch
# Epoch 2/10 Iteration: 7800 Avg. Training loss: 4.3521 0.0226 sec/batch
# Epoch 2/10 Iteration: 7900 Avg. Training loss: 4.3196 0.0226 sec/batch
# Epoch 2/10 Iteration: 8000 Avg. Training loss: 4.3246 0.0225 sec/batch
# Nearest to his: daughter, tutti, wife, appalled, dogma, worship, genius, anglorum,
# Nearest to where: seconda, interruptions, arctic, tried, ringed, dinara, slacks, objects,
# Nearest to to: requisite, marbles, offices, sketched, northumbrian, jomo, something, concerning,
# Nearest to after: loc, astute, cumbric, depot, declaring, fled, other, lusitanian,
# Nearest to so: said, orthogonality, chani, odysseus, foobar, snakes, prabang, cornhuskers,
# Nearest to of: handmaid, decree, massif, squarely, macho, retainers, the, diazonium,
# Nearest to that: not, believed, mss, quintessential, prove, plato, deadlocked, calwell,
# Nearest to all: lexicographic, unacceptable, shingon, kraftwerk, sectarianism, espy, possible, condom,
# Nearest to discovered: lumbar, boss, rourke, ssbauer, organon, mesons, dedekind, lector,
# Nearest to placed: delphic, remain, kaveri, puddle, bodies, fishes, fractured, johansen,
# Nearest to hit: hara, yzerman, defensive, algiris, landings, band, paddling, hailie,
# Nearest to arts: rivaling, raising, refrains, patriarchates, tra, hervarar, quartier, cabral,
# Nearest to cost: filename, valo, variety, excel, stove, vicugna, attenuated, service,
# Nearest to professional: vase, irving, laying, dynamically, brand, shocked, tatsam, tauranac,
# Nearest to freedom: heads, publicly, communism, uncontroversial, coinages, codepoint, freedoms, leaders,
# Nearest to smith: owl, modular, thinly, opening, dontrelle, vance, anguished, developer,
# Epoch 2/10 Iteration: 8100 Avg. Training loss: 4.3165 0.0233 sec/batch
# Epoch 2/10 Iteration: 8200 Avg. Training loss: 4.2738 0.0228 sec/batch
# Epoch 2/10 Iteration: 8300 Avg. Training loss: 4.3684 0.0227 sec/batch
# Epoch 2/10 Iteration: 8400 Avg. Training loss: 4.3682 0.0226 sec/batch
# Epoch 2/10 Iteration: 8500 Avg. Training loss: 4.4000 0.0226 sec/batch
# Epoch 2/10 Iteration: 8600 Avg. Training loss: 4.2703 0.0227 sec/batch
# Epoch 2/10 Iteration: 8700 Avg. Training loss: 4.3070 0.0225 sec/batch
# Epoch 2/10 Iteration: 8800 Avg. Training loss: 4.3529 0.0226 sec/batch
# Epoch 2/10 Iteration: 8900 Avg. Training loss: 4.2067 0.0226 sec/batch
# Epoch 2/10 Iteration: 9000 Avg. Training loss: 4.2726 0.0226 sec/batch
# Nearest to his: tutti, daughter, wife, boiler, dogma, preoccupation, abijah, alienated,
# Nearest to where: interruptions, seconda, tried, arctic, slacks, dinara, ringed, embolism,
# Nearest to to: marbles, requisite, offices, jomo, northumbrian, sketched, something, off,
# Nearest to after: loc, declaring, veritable, emmylou, depot, astute, superfamilies, confederal,
# Nearest to so: said, orthogonality, prabang, odysseus, chani, foobar, cornhuskers, hindering,
# Nearest to of: handmaid, the, decree, massif, diazonium, squarely, retainers, protestant,
# Nearest to that: not, prove, deadlocked, sinaiticus, seduced, calwell, plato, believed,
# Nearest to all: lexicographic, shingon, espy, kraftwerk, unacceptable, condom, sectarianism, ling,
# Nearest to discovered: lumbar, boss, ssbauer, mesons, rourke, marbles, organon, dedekind,
# Nearest to placed: remain, delphic, kaveri, bodies, puddle, fishes, fractured, placekicker,
# Nearest to hit: yzerman, hara, defensive, algiris, band, squealer, landings, endless,
# Nearest to arts: rivaling, raising, hervarar, infertile, refrains, quartier, attestation, patriarchates,
# Nearest to cost: filename, valo, excel, variety, stove, nicer, liberalization, service,
# Nearest to professional: vase, irving, laying, brand, tauranac, dynamically, shocked, tatsam,
# Nearest to freedom: heads, publicly, communism, uncontroversial, codepoint, coinages, voluntary, leaders,
# Nearest to smith: owl, modular, dontrelle, anguished, vance, thinly, rothbard, opening,
# Epoch 2/10 Iteration: 9100 Avg. Training loss: 4.3201 0.0233 sec/batch
# Epoch 2/10 Iteration: 9200 Avg. Training loss: 4.3220 0.0225 sec/batch
# Epoch 3/10 Iteration: 9300 Avg. Training loss: 4.3378 0.0101 sec/batch
# Epoch 3/10 Iteration: 9400 Avg. Training loss: 4.2426 0.0225 sec/batch
# Epoch 3/10 Iteration: 9500 Avg. Training loss: 4.2299 0.0226 sec/batch
# Epoch 3/10 Iteration: 9600 Avg. Training loss: 4.2190 0.0226 sec/batch
# Epoch 3/10 Iteration: 9700 Avg. Training loss: 4.2372 0.0226 sec/batch
# Epoch 3/10 Iteration: 9800 Avg. Training loss: 4.2092 0.0226 sec/batch
# Epoch 3/10 Iteration: 9900 Avg. Training loss: 4.2204 0.0225 sec/batch
# Epoch 3/10 Iteration: 10000 Avg. Training loss: 4.1660 0.0226 sec/batch
# Nearest to his: tutti, daughter, abijah, dogma, wife, boiler, alienated, preoccupation,
# Nearest to where: interruptions, seconda, tried, arctic, slacks, ringed, reclaimed, dinara,
# Nearest to to: off, requisite, something, marbles, tether, kal, goals, offices,
# Nearest to after: loc, declaring, confederal, veritable, astute, fury, superfamilies, emmylou,
# Nearest to so: said, orthogonality, odysseus, chani, prabang, foobar, cornhuskers, snakes,
# Nearest to of: handmaid, the, ordain, arawak, massif, salaam, diazonium, kerensky,
# Nearest to that: deadlocked, calwell, sinaiticus, prove, enacted, mss, not, seduced,
# Nearest to all: lexicographic, shingon, kraftwerk, overhanging, espy, ling, condom, entirely,
# Nearest to discovered: lumbar, ssbauer, phenols, boss, reconquering, mesons, organon, marbles,
# Nearest to placed: delphic, remain, bodies, kaveri, puddle, fractured, fishes, nose,
# Nearest to hit: defensive, yzerman, hara, reaper, shorts, algiris, saipan, paddling,
# Nearest to arts: rivaling, raising, hervarar, tra, refrains, quartier, infertile, assuage,
# Nearest to cost: filename, excel, valo, service, stove, variety, cuboctahedra, sncf,
# Nearest to professional: irving, laying, vase, brand, dynamically, tauranac, shocked, centennial,
# Nearest to freedom: heads, communism, publicly, simplicity, coinages, freedoms, socialism, uncontroversial,
# Nearest to smith: owl, modular, dontrelle, anguished, thinly, opening, steed, rothbard,
# Epoch 3/10 Iteration: 10100 Avg. Training loss: 4.2529 0.0233 sec/batch
# Epoch 3/10 Iteration: 10200 Avg. Training loss: 4.2405 0.0225 sec/batch
# Epoch 3/10 Iteration: 10300 Avg. Training loss: 4.2309 0.0226 sec/batch
# Epoch 3/10 Iteration: 10400 Avg. Training loss: 4.1494 0.0226 sec/batch
# Epoch 3/10 Iteration: 10500 Avg. Training loss: 4.1608 0.0226 sec/batch
# Epoch 3/10 Iteration: 10600 Avg. Training loss: 4.1460 0.0225 sec/batch
# Epoch 3/10 Iteration: 10700 Avg. Training loss: 4.1704 0.0227 sec/batch
# Epoch 3/10 Iteration: 10800 Avg. Training loss: 4.1506 0.0227 sec/batch
# Epoch 3/10 Iteration: 10900 Avg. Training loss: 4.1882 0.0228 sec/batch
# Epoch 3/10 Iteration: 11000 Avg. Training loss: 4.1697 0.0227 sec/batch
# Nearest to his: tutti, daughter, appalled, alienated, wife, abijah, preoccupation, rechristened,
# Nearest to where: interruptions, seconda, tried, ringed, slacks, arctic, pony, will,
# Nearest to to: off, requisite, marbles, centralization, offices, goals, tether, something,
# Nearest to after: loc, astute, veritable, fury, confederal, declaring, emmylou, superfamilies,
# Nearest to so: orthogonality, said, prabang, foobar, chani, odysseus, hindering, cornhuskers,
# Nearest to of: the, handmaid, naturalists, disturb, massif, ordain, diazonium, mantis,
# Nearest to that: prove, deadlocked, not, calwell, out, enacted, believed, mss,
# Nearest to all: shingon, lexicographic, entirely, sectarianism, kraftwerk, unacceptable, crs, espy,
# Nearest to discovered: lumbar, phenols, mesons, ssbauer, marbles, boss, organon, dedekind,
# Nearest to placed: delphic, remain, bodies, kaveri, puddle, nose, fractured, fishes,
# Nearest to hit: defensive, yzerman, hara, reaper, algiris, saipan, shorts, coordinator,
# Nearest to arts: rivaling, raising, undergraduate, hervarar, attestation, graduate, tra, quartier,
# Nearest to cost: excel, valo, filename, cuboctahedra, sncf, stove, service, liberalization,
# Nearest to professional: irving, laying, vase, brand, dynamically, shocked, tauranac, centennial,
# Nearest to freedom: communism, publicly, heads, freedoms, socialism, nasdaq, simplicity, liberalism,
# Nearest to smith: owl, modular, dontrelle, anguished, developer, rothbard, steed, nancy,
# Epoch 3/10 Iteration: 11100 Avg. Training loss: 4.1757 0.0233 sec/batch
# Epoch 3/10 Iteration: 11200 Avg. Training loss: 4.2182 0.0227 sec/batch
# Epoch 3/10 Iteration: 11300 Avg. Training loss: 4.1664 0.0227 sec/batch
# Epoch 3/10 Iteration: 11400 Avg. Training loss: 4.1782 0.0225 sec/batch
# Epoch 3/10 Iteration: 11500 Avg. Training loss: 4.1788 0.0226 sec/batch
# Epoch 3/10 Iteration: 11600 Avg. Training loss: 4.1832 0.0225 sec/batch
# Epoch 3/10 Iteration: 11700 Avg. Training loss: 4.1901 0.0226 sec/batch
# Epoch 3/10 Iteration: 11800 Avg. Training loss: 4.1379 0.0225 sec/batch
# Epoch 3/10 Iteration: 11900 Avg. Training loss: 4.1532 0.0226 sec/batch
# Epoch 3/10 Iteration: 12000 Avg. Training loss: 4.1997 0.0226 sec/batch
# Nearest to his: tutti, daughter, tragically, genius, he, alienated, abijah, cosell,
# Nearest to where: seconda, interruptions, tried, pony, will, slacks, ringed, villard,
# Nearest to to: centralization, sketched, off, requisite, offices, tether, jomo, sapporo,
# Nearest to after: loc, declaring, astute, fury, veritable, confederal, crispus, packer,
# Nearest to so: orthogonality, prabang, said, chani, foobar, odysseus, lathes, hindering,
# Nearest to of: the, handmaid, negative, macho, disturb, is, computability, decree,
# Nearest to that: prove, deadlocked, not, sinaiticus, out, believed, this, philosophical,
# Nearest to all: entirely, lexicographic, shingon, espy, overhanging, kraftwerk, unacceptable, sectarianism,
# Nearest to discovered: lumbar, phenols, boss, hominin, ssbauer, dedekind, mesons, marbles,
# Nearest to placed: delphic, remain, bodies, kaveri, fractured, puddle, cortina, nose,
# Nearest to hit: defensive, yzerman, hara, algiris, coordinator, saipan, danny, reaper,
# Nearest to arts: rivaling, graduate, tenured, students, undergraduate, memoirists, raising, universities,
# Nearest to cost: valo, excel, sncf, stove, filename, cuboctahedra, nicer, liberalization,
# Nearest to professional: irving, vase, laying, brand, centennial, dynamically, shocked, tauranac,
# Nearest to freedom: communism, publicly, freedoms, heads, liberalism, socialism, codepoint, simplicity,
# Nearest to smith: modular, owl, dontrelle, developer, rothbard, nancy, anguished, harrow,
# Epoch 3/10 Iteration: 12100 Avg. Training loss: 4.1989 0.0232 sec/batch
# Epoch 3/10 Iteration: 12200 Avg. Training loss: 4.1866 0.0227 sec/batch
# Epoch 3/10 Iteration: 12300 Avg. Training loss: 4.1822 0.0226 sec/batch
# Epoch 3/10 Iteration: 12400 Avg. Training loss: 4.1808 0.0226 sec/batch
# Epoch 3/10 Iteration: 12500 Avg. Training loss: 4.1437 0.0226 sec/batch
# Epoch 3/10 Iteration: 12600 Avg. Training loss: 4.1230 0.0226 sec/batch
# Epoch 3/10 Iteration: 12700 Avg. Training loss: 4.1456 0.0226 sec/batch
# Epoch 3/10 Iteration: 12800 Avg. Training loss: 4.1432 0.0228 sec/batch
# Epoch 3/10 Iteration: 12900 Avg. Training loss: 4.1776 0.0227 sec/batch
# Epoch 3/10 Iteration: 13000 Avg. Training loss: 4.2277 0.0227 sec/batch
# Nearest to his: tutti, he, daughter, tragically, schooling, genius, preoccupation, alienated,
# Nearest to where: interruptions, tried, seconda, pony, will, reclaimed, tria, kimberley,
# Nearest to to: insurrection, offices, s, who, tether, habilitation, goals, jomo,
# Nearest to after: loc, declaring, fury, crispus, confederal, veritable, astute, emmylou,
# Nearest to so: prabang, said, chani, orthogonality, odysseus, cornhuskers, dicotyledonous, foobar,
# Nearest to of: the, decree, chancellors, kerensky, quadi, archdukes, huber, retainers,
# Nearest to that: deadlocked, sinaiticus, prove, seduced, not, calwell, out, believed,
# Nearest to all: entirely, shingon, espy, overhanging, lexicographic, sectarianism, recur, kraftwerk,
# Nearest to discovered: lumbar, dedekind, hominin, ssbauer, marbles, boss, watcher, rainer,
# Nearest to placed: delphic, remain, bodies, fractured, kaveri, cortina, puddle, nose,
# Nearest to hit: yzerman, defensive, hara, saipan, algiris, reaper, coordinator, paddling,
# Nearest to arts: rivaling, graduate, tenured, polytechnic, alumnus, ararat, students, memoirists,
# Nearest to cost: valo, excel, sncf, liberalization, reorganised, stove, cuboctahedra, nicer,
# Nearest to professional: irving, laying, vase, brand, tauranac, centennial, shocked, dynamically,
# Nearest to freedom: communism, publicly, socialism, freedoms, liberalism, heads, coinages, nasdaq,
# Nearest to smith: modular, owl, dontrelle, developer, rothbard, nancy, excavators, anguished,
# Epoch 3/10 Iteration: 13100 Avg. Training loss: 4.2499 0.0232 sec/batch
# Epoch 3/10 Iteration: 13200 Avg. Training loss: 4.1424 0.0226 sec/batch
# Epoch 3/10 Iteration: 13300 Avg. Training loss: 4.1360 0.0225 sec/batch
# Epoch 3/10 Iteration: 13400 Avg. Training loss: 4.1449 0.0225 sec/batch
# Epoch 3/10 Iteration: 13500 Avg. Training loss: 4.0240 0.0226 sec/batch
# Epoch 3/10 Iteration: 13600 Avg. Training loss: 4.1267 0.0226 sec/batch
# Epoch 3/10 Iteration: 13700 Avg. Training loss: 4.1325 0.0225 sec/batch
# Epoch 3/10 Iteration: 13800 Avg. Training loss: 4.1577 0.0225 sec/batch
# Epoch 4/10 Iteration: 13900 Avg. Training loss: 4.1432 0.0038 sec/batch
# Epoch 4/10 Iteration: 14000 Avg. Training loss: 4.1600 0.0225 sec/batch
# Nearest to his: tutti, he, tragically, daughter, schooling, genius, alienated, giedi,
# Nearest to where: interruptions, tried, seconda, will, pony, ringed, villard, reclaimed,
# Nearest to to: tether, off, s, centralization, bloomberg, goals, something, requisite,
# Nearest to after: loc, declaring, crispus, veritable, fury, confederal, emmylou, astute,
# Nearest to so: prabang, orthogonality, said, chani, lathes, foobar, hindering, dicotyledonous,
# Nearest to of: the, arawak, massif, is, handmaid, important, eusocial, quadi,
# Nearest to that: prove, deadlocked, this, not, sinaiticus, infinitesimally, problem, ought,
# Nearest to all: entirely, espy, overhanging, perrin, shingon, lexicographic, googolplex, kraftwerk,
# Nearest to discovered: lumbar, dedekind, marbles, mesons, hominin, ssbauer, phenols, watcher,
# Nearest to placed: delphic, remain, bodies, cortina, fractured, kaveri, nose, puddle,
# Nearest to hit: defensive, yzerman, saipan, hara, algiris, coordinator, reaper, paddling,
# Nearest to arts: rivaling, tenured, graduate, sonnets, overlooked, patriarchates, universities, undergraduate,
# Nearest to cost: valo, excel, sncf, nicer, liberalization, cuboctahedra, turbo, filename,
# Nearest to professional: irving, laying, brand, shocked, vase, dynamically, tauranac, expressive,
# Nearest to freedom: communism, freedoms, socialism, publicly, liberalism, heads, simplicity, anarchist,
# Nearest to smith: owl, dontrelle, modular, developer, rothbard, nancy, excavators, anguished,
# Epoch 4/10 Iteration: 14100 Avg. Training loss: 4.0751 0.0233 sec/batch
# Epoch 4/10 Iteration: 14200 Avg. Training loss: 4.0894 0.0226 sec/batch
# Epoch 4/10 Iteration: 14300 Avg. Training loss: 4.0832 0.0225 sec/batch
# Epoch 4/10 Iteration: 14400 Avg. Training loss: 4.0543 0.0226 sec/batch
# Epoch 4/10 Iteration: 14500 Avg. Training loss: 4.0993 0.0227 sec/batch
# Epoch 4/10 Iteration: 14600 Avg. Training loss: 4.0563 0.0226 sec/batch
# Epoch 4/10 Iteration: 14700 Avg. Training loss: 4.0881 0.0225 sec/batch
# Epoch 4/10 Iteration: 14800 Avg. Training loss: 4.1252 0.0226 sec/batch
# Epoch 4/10 Iteration: 14900 Avg. Training loss: 4.1065 0.0225 sec/batch
# Epoch 4/10 Iteration: 15000 Avg. Training loss: 4.0503 0.0226 sec/batch
# Nearest to his: tutti, he, daughter, tragically, abijah, wife, genius, schooling,
# Nearest to where: interruptions, tried, seconda, pony, will, reclaimed, villard, slacks,
# Nearest to to: off, tether, syrians, back, goals, s, tachelhit, centralization,
# Nearest to after: loc, declaring, veritable, crispus, confederal, nba, fury, superintendent,
# Nearest to so: prabang, orthogonality, lathes, said, odysseus, foobar, chani, already,
# Nearest to of: the, arawak, handmaid, ordain, is, yearly, exalts, disturb,
# Nearest to that: prove, this, saying, deadlocked, calwell, not, believed, luminous,
# Nearest to all: entirely, shingon, perrin, sectarianism, espy, overhanging, kraftwerk, annotation,
# Nearest to discovered: lumbar, phenols, marbles, mesons, hominin, ssbauer, furnaces, dedekind,
# Nearest to placed: delphic, remain, bodies, kaveri, fractured, cortina, nose, puddle,
# Nearest to hit: yzerman, defensive, saipan, hara, reaper, coordinator, algiris, bounce,
# Nearest to arts: rivaling, tenured, graduate, universities, undergraduate, alumnus, patriarchates, students,
# Nearest to cost: valo, excel, sncf, cuboctahedra, liberalization, stove, nodens, reorganised,
# Nearest to professional: irving, laying, brand, shocked, leagues, juniors, arena, tauranac,
# Nearest to freedom: communism, socialism, freedoms, liberalism, publicly, anarchist, simplicity, nasdaq,
# Nearest to smith: modular, owl, rothbard, dontrelle, developer, nancy, excavators, anguished,
# Epoch 4/10 Iteration: 15100 Avg. Training loss: 4.0239 0.0233 sec/batch
# Epoch 4/10 Iteration: 15200 Avg. Training loss: 4.0185 0.0226 sec/batch
# Epoch 4/10 Iteration: 15300 Avg. Training loss: 4.0055 0.0225 sec/batch
# Epoch 4/10 Iteration: 15400 Avg. Training loss: 4.0603 0.0226 sec/batch
# Epoch 4/10 Iteration: 15500 Avg. Training loss: 4.0704 0.0226 sec/batch
# Epoch 4/10 Iteration: 15600 Avg. Training loss: 4.0384 0.0226 sec/batch
# Epoch 4/10 Iteration: 15700 Avg. Training loss: 4.0489 0.0226 sec/batch
# Epoch 4/10 Iteration: 15800 Avg. Training loss: 4.0921 0.0225 sec/batch
# Epoch 4/10 Iteration: 15900 Avg. Training loss: 4.0512 0.0226 sec/batch
# Epoch 4/10 Iteration: 16000 Avg. Training loss: 4.0388 0.0225 sec/batch
# Nearest to his: tutti, he, tragically, daughter, genius, schooling, wife, giedi,
# Nearest to where: interruptions, seconda, tried, will, swelling, pony, discordant, ringed,
# Nearest to to: off, tether, centralization, requisite, bloomberg, containers, assuming, something,
# Nearest to after: loc, declaring, crispus, emmylou, nba, superintendent, veritable, fury,
# Nearest to so: prabang, orthogonality, lathes, foobar, already, dicotyledonous, odysseus, said,
# Nearest to of: the, is, transformations, has, which, disturb, metaphysics, crystallize,
# Nearest to that: not, this, prove, deadlocked, out, problem, believed, interpretation,
# Nearest to all: entirely, shingon, recur, microseconds, sectarianism, perrin, lexicographic, googolplex,
# Nearest to discovered: lumbar, phenols, marbles, dedekind, hominin, mesons, ssbauer, inhaled,
# Nearest to placed: delphic, remain, bodies, kaveri, cortina, puddle, fractured, chute,
# Nearest to hit: yzerman, defensive, saipan, newcomers, hara, being, paddling, algiris,
# Nearest to arts: rivaling, tenured, polytechnic, academy, graduate, sonnets, progenitors, patriarchates,
# Nearest to cost: valo, excel, sncf, stove, cuboctahedra, atheism, turbo, liberalization,
# Nearest to professional: irving, laying, expressive, brand, leagues, shocked, juniors, arena,
# Nearest to freedom: communism, socialism, freedoms, liberalism, publicly, heads, anarchist, nasdaq,
# Nearest to smith: modular, dontrelle, owl, rothbard, developer, nancy, excavators, mendel,
# Epoch 4/10 Iteration: 16100 Avg. Training loss: 4.0360 0.0233 sec/batch
# Epoch 4/10 Iteration: 16200 Avg. Training loss: 4.0651 0.0226 sec/batch
# Epoch 4/10 Iteration: 16300 Avg. Training loss: 4.0729 0.0226 sec/batch
# Epoch 4/10 Iteration: 16400 Avg. Training loss: 4.0562 0.0225 sec/batch
# Epoch 4/10 Iteration: 16500 Avg. Training loss: 4.0813 0.0226 sec/batch
# Epoch 4/10 Iteration: 16600 Avg. Training loss: 4.0413 0.0226 sec/batch
# Epoch 4/10 Iteration: 16700 Avg. Training loss: 4.0596 0.0225 sec/batch
# Epoch 4/10 Iteration: 16800 Avg. Training loss: 4.0342 0.0226 sec/batch
# Epoch 4/10 Iteration: 16900 Avg. Training loss: 4.0905 0.0226 sec/batch
# Epoch 4/10 Iteration: 17000 Avg. Training loss: 4.0620 0.0226 sec/batch
# Nearest to his: he, tutti, tragically, daughter, schooling, genius, abijah, preoccupation,
# Nearest to where: interruptions, tried, seconda, pony, will, tria, slacks, villard,
# Nearest to to: off, sapporo, philippi, tether, the, bloomberg, who, s,
# Nearest to after: crispus, piotr, loc, declaring, veritable, confederal, superintendent, beholden,
# Nearest to so: prabang, already, orthogonality, lathes, odysseus, dicotyledonous, said, galego,
# Nearest to of: the, arawak, in, archdukes, disturb, which, ordain, yearly,
# Nearest to that: prove, this, deadlocked, saying, positivist, not, believed, out,
# Nearest to all: entirely, commemoration, shingon, recur, espy, wffs, perrin, lexicographic,
# Nearest to discovered: dedekind, lumbar, hominin, marbles, ssbauer, phenols, rainer, watcher,
# Nearest to placed: delphic, remain, kaveri, bodies, cortina, fractured, puddle, nose,
# Nearest to hit: yzerman, saipan, defensive, frankie, hara, orgy, live, newcomers,
# Nearest to arts: rivaling, tenured, academy, alumnus, progenitors, sonnets, graduate, polytechnic,
# Nearest to cost: valo, excel, sncf, stove, atheism, reorganised, cuboctahedra, nicer,
# Nearest to professional: irving, laying, expressive, brand, juniors, shocked, centennial, leagues,
# Nearest to freedom: freedoms, communism, socialism, liberalism, publicly, heads, simplicity, anarchist,
# Nearest to smith: dontrelle, modular, rothbard, owl, developer, nancy, excavators, mendel,
# Epoch 4/10 Iteration: 17100 Avg. Training loss: 4.0469 0.0233 sec/batch
# Epoch 4/10 Iteration: 17200 Avg. Training loss: 4.0188 0.0226 sec/batch
# Epoch 4/10 Iteration: 17300 Avg. Training loss: 4.0138 0.0225 sec/batch
# Epoch 4/10 Iteration: 17400 Avg. Training loss: 4.0578 0.0227 sec/batch
# Epoch 4/10 Iteration: 17500 Avg. Training loss: 4.0545 0.0227 sec/batch
# Epoch 4/10 Iteration: 17600 Avg. Training loss: 4.1107 0.0226 sec/batch
# Epoch 4/10 Iteration: 17700 Avg. Training loss: 4.1307 0.0226 sec/batch
# Epoch 4/10 Iteration: 17800 Avg. Training loss: 4.0370 0.0226 sec/batch
# Epoch 4/10 Iteration: 17900 Avg. Training loss: 4.0282 0.0226 sec/batch
# Epoch 4/10 Iteration: 18000 Avg. Training loss: 4.0614 0.0225 sec/batch
# Nearest to his: he, schooling, tragically, tutti, genius, ipn, daughter, discharge,
# Nearest to where: interruptions, seconda, tried, pony, will, villard, swelling, tria,
# Nearest to to: off, tachelhit, tether, bloomberg, sapporo, sketched, syrians, s,
# Nearest to after: loc, crispus, superintendent, beholden, declaring, guarantees, nba, veritable,
# Nearest to so: prabang, orthogonality, lathes, already, odysseus, chani, expands, galego,
# Nearest to of: the, transformations, stamford, arawak, in, archdukes, yearly, is,
# Nearest to that: this, prove, not, positivist, saying, deadlocked, out, ought,
# Nearest to all: commemoration, recur, entirely, espy, perrin, wffs, istrian, pe,
# Nearest to discovered: hominin, dedekind, lumbar, marbles, ssbauer, pauling, watcher, phenols,
# Nearest to placed: delphic, remain, bodies, kaveri, cortina, posterity, puddle, fractured,
# Nearest to hit: yzerman, saipan, defensive, newcomers, being, nefarious, algiris, frankie,
# Nearest to arts: rivaling, tenured, academy, martial, ararat, sonnets, universities, polytechnic,
# Nearest to cost: valo, excel, nicer, sncf, atheism, cuboctahedra, reorganised, stove,
# Nearest to professional: irving, laying, expressive, brand, juniors, shocked, lacrosse, centennial,
# Nearest to freedom: freedoms, socialism, communism, liberalism, publicly, heads, sufficiency, anarchist,
# Nearest to smith: dontrelle, owl, modular, rothbard, developer, nancy, mendel, excavators,
# Epoch 4/10 Iteration: 18100 Avg. Training loss: 3.9585 0.0233 sec/batch
# Epoch 4/10 Iteration: 18200 Avg. Training loss: 4.0218 0.0226 sec/batch
# Epoch 4/10 Iteration: 18300 Avg. Training loss: 4.0392 0.0226 sec/batch
# Epoch 4/10 Iteration: 18400 Avg. Training loss: 4.0499 0.0226 sec/batch
# Epoch 4/10 Iteration: 18500 Avg. Training loss: 4.0774 0.0225 sec/batch
# Epoch 5/10 Iteration: 18600 Avg. Training loss: 4.0313 0.0201 sec/batch
# Epoch 5/10 Iteration: 18700 Avg. Training loss: 4.0366 0.0226 sec/batch
# Epoch 5/10 Iteration: 18800 Avg. Training loss: 3.9787 0.0227 sec/batch
# Epoch 5/10 Iteration: 18900 Avg. Training loss: 4.0163 0.0226 sec/batch
# Epoch 5/10 Iteration: 19000 Avg. Training loss: 3.9815 0.0226 sec/batch
# Nearest to his: he, tragically, tutti, schooling, daughter, abijah, genius, discharge,
# Nearest to where: interruptions, tried, seconda, pony, tria, will, swelling, villard,
# Nearest to to: off, tether, sapporo, s, bloomberg, back, sketched, syrians,
# Nearest to after: crispus, loc, beholden, declaring, superintendent, nba, veritable, guarantees,
# Nearest to so: prabang, orthogonality, lathes, already, almighty, galego, dicotyledonous, odysseus,
# Nearest to of: the, arawak, this, transformations, has, stamford, ethno, disputing,
# Nearest to that: this, positivist, prove, not, ought, saying, deadlocked, just,
# Nearest to all: commemoration, entirely, istrian, perrin, wffs, recur, fore, mullet,
# Nearest to discovered: marbles, hominin, dedekind, inhaled, lumbar, phenols, ssbauer, pauling,
# Nearest to placed: delphic, remain, kaveri, posterity, bodies, cortina, fractured, leipzig,
# Nearest to hit: yzerman, saipan, defensive, newcomers, squealer, nefarious, cannae, hara,
# Nearest to arts: martial, rivaling, tenured, sonnets, academy, alumnus, progenitors, ararat,
# Nearest to cost: excel, valo, atheism, nicer, sncf, cuboctahedra, reorganised, turbo,
# Nearest to professional: laying, expressive, irving, brand, juniors, shocked, arena, lacrosse,
# Nearest to freedom: freedoms, communism, socialism, liberalism, heads, publicly, simplicity, sufficiency,
# Nearest to smith: dontrelle, modular, rothbard, owl, nancy, mendel, developer, executors,
# Epoch 5/10 Iteration: 19100 Avg. Training loss: 3.9909 0.0233 sec/batch
# Epoch 5/10 Iteration: 19200 Avg. Training loss: 3.9607 0.0226 sec/batch
# Epoch 5/10 Iteration: 19300 Avg. Training loss: 3.9976 0.0226 sec/batch
# Epoch 5/10 Iteration: 19400 Avg. Training loss: 4.0313 0.0226 sec/batch
# Epoch 5/10 Iteration: 19500 Avg. Training loss: 4.0222 0.0226 sec/batch
# Epoch 5/10 Iteration: 19600 Avg. Training loss: 4.0066 0.0227 sec/batch
# Epoch 5/10 Iteration: 19700 Avg. Training loss: 3.9042 0.0226 sec/batch
# Epoch 5/10 Iteration: 19800 Avg. Training loss: 3.9645 0.0226 sec/batch
# Epoch 5/10 Iteration: 19900 Avg. Training loss: 3.9707 0.0226 sec/batch
# Epoch 5/10 Iteration: 20000 Avg. Training loss: 3.9996 0.0226 sec/batch
# Nearest to his: he, tragically, tutti, schooling, had, daughter, abijah, genius,
# Nearest to where: interruptions, seconda, tried, pony, will, swelling, are, tria,
# Nearest to to: off, the, granting, and, tachelhit, philippi, back, s,
# Nearest to after: crispus, loc, beholden, mane, declaring, superintendent, veritable, nba,
# Nearest to so: lathes, already, prabang, orthogonality, expands, him, said, almighty,
# Nearest to of: the, is, has, in, a, transformations, which, this,
# Nearest to that: not, this, prove, positivist, ought, out, saying, deadlocked,
# Nearest to all: microseconds, entirely, commemoration, perrin, surjective, istrian, recur, pe,
# Nearest to discovered: dedekind, hominin, marbles, inhaled, spores, phenols, ssbauer, mesons,
# Nearest to placed: delphic, remain, kaveri, bodies, posterity, cortina, secures, recuperate,
# Nearest to hit: saipan, yzerman, defensive, newcomers, cannae, nefarious, being, algiris,
# Nearest to arts: martial, rivaling, tenured, academy, sonnets, alumnus, schools, polytechnic,
# Nearest to cost: atheism, excel, valo, cuboctahedra, sncf, nicer, reorganised, stove,
# Nearest to professional: laying, expressive, readiness, juniors, irving, leagues, brand, lacrosse,
# Nearest to freedom: freedoms, socialism, communism, liberalism, nasdaq, heads, simplicity, sufficiency,
# Nearest to smith: rothbard, dontrelle, modular, owl, developer, duplicates, nancy, mendel,
# Epoch 5/10 Iteration: 20100 Avg. Training loss: 4.0159 0.0233 sec/batch
# Epoch 5/10 Iteration: 20200 Avg. Training loss: 4.0136 0.0226 sec/batch
# Epoch 5/10 Iteration: 20300 Avg. Training loss: 3.9658 0.0226 sec/batch
# Epoch 5/10 Iteration: 20400 Avg. Training loss: 4.0121 0.0226 sec/batch
# Epoch 5/10 Iteration: 20500 Avg. Training loss: 4.0328 0.0226 sec/batch
# Epoch 5/10 Iteration: 20600 Avg. Training loss: 3.9592 0.0226 sec/batch
# Epoch 5/10 Iteration: 20700 Avg. Training loss: 4.0150 0.0226 sec/batch
# Epoch 5/10 Iteration: 20800 Avg. Training loss: 3.9932 0.0226 sec/batch
# Epoch 5/10 Iteration: 20900 Avg. Training loss: 3.9838 0.0226 sec/batch
# Epoch 5/10 Iteration: 21000 Avg. Training loss: 4.0058 0.0226 sec/batch
# Nearest to his: he, schooling, tragically, tutti, abijah, genius, had, ipn,
# Nearest to where: interruptions, seconda, tria, tried, will, withdrawn, pony, villard,
# Nearest to to: sketched, off, bloomberg, s, assuming, mantras, the, lunas,
# Nearest to after: crispus, beholden, loc, superintendent, declaring, piotr, veritable, mane,
# Nearest to so: lathes, orthogonality, already, prabang, almighty, expands, him, said,
# Nearest to of: the, has, is, transformations, a, which, by, this,
# Nearest to that: not, this, prove, positivist, ought, saying, amoraim, deadlocked,
# Nearest to all: commemoration, entirely, perrin, microseconds, espy, sectarianism, a, as,
# Nearest to discovered: dedekind, hominin, marbles, inhaled, lumbar, spores, ssbauer, pauling,
# Nearest to placed: delphic, remain, cortina, kaveri, bodies, posterity, recuperate, puddle,
# Nearest to hit: yzerman, saipan, newcomers, defensive, cannae, nefarious, being, frankie,
# Nearest to arts: martial, academy, rivaling, sonnets, tenured, alumnus, progenitors, students,
# Nearest to cost: valo, excel, atheism, nicer, sncf, reorganised, nodens, cuboctahedra,
# Nearest to professional: expressive, laying, juniors, irving, lacrosse, readiness, leagues, brand,
# Nearest to freedom: freedoms, liberalism, socialism, communism, ifab, heads, nasdaq, publicly,
# Nearest to smith: dontrelle, rothbard, modular, nancy, owl, developer, mendel, degenerated,
# Epoch 5/10 Iteration: 21100 Avg. Training loss: 3.9939 0.0233 sec/batch
# Epoch 5/10 Iteration: 21200 Avg. Training loss: 3.9847 0.0225 sec/batch
# Epoch 5/10 Iteration: 21300 Avg. Training loss: 3.9670 0.0226 sec/batch
# Epoch 5/10 Iteration: 21400 Avg. Training loss: 4.0101 0.0226 sec/batch
# Epoch 5/10 Iteration: 21500 Avg. Training loss: 4.0157 0.0226 sec/batch
# Epoch 5/10 Iteration: 21600 Avg. Training loss: 3.9827 0.0226 sec/batch
# Epoch 5/10 Iteration: 21700 Avg. Training loss: 3.9941 0.0226 sec/batch
# Epoch 5/10 Iteration: 21800 Avg. Training loss: 3.9850 0.0226 sec/batch
# Epoch 5/10 Iteration: 21900 Avg. Training loss: 3.9768 0.0225 sec/batch
# Epoch 5/10 Iteration: 22000 Avg. Training loss: 4.0246 0.0227 sec/batch
# Nearest to his: he, schooling, tragically, tutti, abijah, genius, ipn, daughter,
# Nearest to where: interruptions, seconda, tried, will, are, pony, withdrawn, tria,
# Nearest to to: s, the, and, bloomberg, in, flavian, granting, off,
# Nearest to after: crispus, beholden, loc, piotr, following, veritable, guarantees, superintendent,
# Nearest to so: orthogonality, already, prabang, lathes, galego, expands, dicotyledonous, said,
# Nearest to of: the, in, by, has, a, is, this, which,
# Nearest to that: this, not, saying, prove, deadlocked, ought, amoraim, positivist,
# Nearest to all: commemoration, entirely, a, as, perrin, recur, sectarianism, areas,
# Nearest to discovered: dedekind, hominin, marbles, inhaled, fredrick, pauling, ssbauer, spores,
# Nearest to placed: delphic, remain, posterity, bodies, kaveri, recuperate, iceni, cortina,
# Nearest to hit: yzerman, saipan, cannae, newcomers, nefarious, being, squealer, fang,
# Nearest to arts: martial, academy, sonnets, tenured, rivaling, alumnus, progenitors, students,
# Nearest to cost: excel, valo, atheism, reorganised, sncf, nicer, contractor, nodens,
# Nearest to professional: expressive, laying, juniors, readiness, lacrosse, leagues, irving, brand,
# Nearest to freedom: freedoms, liberalism, socialism, heads, communism, publicly, ifab, sufficiency,
# Nearest to smith: rothbard, dontrelle, modular, owl, mendel, nancy, developer, maxfield,
# Epoch 5/10 Iteration: 22100 Avg. Training loss: 3.9796 0.0235 sec/batch
# Epoch 5/10 Iteration: 22200 Avg. Training loss: 4.0559 0.0226 sec/batch
# Epoch 5/10 Iteration: 22300 Avg. Training loss: 4.0259 0.0226 sec/batch
# ...
# Epoch 9/10 Iteration: 38400 Avg. Training loss: 3.8046 0.0225 sec/batch
# Epoch 9/10 Iteration: 38500 Avg. Training loss: 3.8073 0.0225 sec/batch
# Epoch 9/10 Iteration: 38600 Avg. Training loss: 3.8426 0.0226 sec/batch
# Epoch 9/10 Iteration: 38700 Avg. Training loss: 3.8603 0.0226 sec/batch
# Epoch 9/10 Iteration: 38800 Avg. Training loss: 3.8486 0.0226 sec/batch
# Epoch 9/10 Iteration: 38900 Avg. Training loss: 3.8625 0.0226 sec/batch
# Epoch 9/10 Iteration: 39000 Avg. Training loss: 3.9268 0.0226 sec/batch
# Nearest to his: he, career, genius, himself, tragically, tutti, lifetime, famed,
# Nearest to where: a, are, there, in, be, mandriva, at, interruptions,
# Nearest to to: in, and, the, for, with, that, of, by,
# Nearest to after: following, later, beholden, the, in, was, crispus, backup,
# Nearest to so: not, to, already, caddy, orthogonality, occupy, lathes, started,
# Nearest to of: the, a, and, is, in, by, for, an,
# Nearest to that: a, an, to, be, as, of, in, and,
# Nearest to all: a, only, of, both, are, as, they, will,
# Nearest to discovered: inhaled, discovery, hominin, dedekind, landed, lamiaceae, colony, fredrick,
# Nearest to placed: delphic, secures, remain, exclusively, scientists, fractures, masks, display,
# Nearest to hit: cannae, fang, atoll, johanson, hitting, being, peaked, penetrate,
# Nearest to arts: martial, academy, progenitors, tenured, gendai, rivaling, practitioner, hochschule,
# Nearest to cost: excel, atheism, attenuated, nodens, crack, cheaper, cuboctahedra, programmability,
# Nearest to professional: golfer, readiness, expressive, brand, juniors, warhawk, leagues, badminton,
# Nearest to freedom: freedoms, liberalism, dissociate, glorify, herd, leftists, ifab, promotes,
# Nearest to smith: rothbard, dontrelle, modular, opiate, degenerated, owl, maxfield, yakima,
# Epoch 9/10 Iteration: 39100 Avg. Training loss: 3.8171 0.0233 sec/batch
# Epoch 9/10 Iteration: 39200 Avg. Training loss: 3.8372 0.0225 sec/batch
# Epoch 9/10 Iteration: 39300 Avg. Training loss: 3.8625 0.0226 sec/batch
# Epoch 9/10 Iteration: 39400 Avg. Training loss: 3.8753 0.0226 sec/batch
# Epoch 9/10 Iteration: 39500 Avg. Training loss: 3.8455 0.0225 sec/batch
# Epoch 9/10 Iteration: 39600 Avg. Training loss: 3.8939 0.0226 sec/batch
# Epoch 9/10 Iteration: 39700 Avg. Training loss: 3.8529 0.0226 sec/batch
# Epoch 9/10 Iteration: 39800 Avg. Training loss: 3.8364 0.0225 sec/batch
# Epoch 9/10 Iteration: 39900 Avg. Training loss: 3.8861 0.0226 sec/batch
# Epoch 9/10 Iteration: 40000 Avg. Training loss: 3.8489 0.0226 sec/batch
# Nearest to his: he, career, genius, lifetime, himself, abitur, entered, famed,
# Nearest to where: a, in, tried, be, tria, are, mandriva, dolly,
# Nearest to to: in, the, and, of, with, for, s, that,
# Nearest to after: following, later, the, was, beholden, in, soon, crispus,
# Nearest to so: already, not, started, caddy, occupy, orthogonality, to, dicotyledonous,
# Nearest to of: the, by, and, in, a, also, is, for,
# Nearest to that: an, as, and, be, a, in, of, to,
# Nearest to all: a, both, only, of, as, are, commemoration, they,
# Nearest to discovered: discovery, dedekind, inhaled, hominin, landed, rainer, colony, pauling,
# Nearest to placed: secures, delphic, exclusively, remain, scientists, masks, fractures, recuperate,
# Nearest to hit: fang, johanson, atoll, cannae, peaked, hitting, penetrate, nefarious,
# Nearest to arts: martial, academy, progenitors, gendai, tenured, rivaling, hochschule, cashmere,
# Nearest to cost: excel, atheism, cheaper, attenuated, crack, nodens, valo, holstein,
# Nearest to professional: golfer, readiness, expressive, warhawk, brand, juniors, centennial, badminton,
# Nearest to freedom: freedoms, liberalism, dissociate, herd, leftists, foia, equate, free,
# Nearest to smith: rothbard, degenerated, modular, dontrelle, opiate, codex, owl, maxfield,
# Epoch 9/10 Iteration: 40100 Avg. Training loss: 3.8570 0.0233 sec/batch
# Epoch 9/10 Iteration: 40200 Avg. Training loss: 3.8441 0.0226 sec/batch
# Epoch 9/10 Iteration: 40300 Avg. Training loss: 3.8132 0.0226 sec/batch
# Epoch 9/10 Iteration: 40400 Avg. Training loss: 3.8371 0.0225 sec/batch
# Epoch 9/10 Iteration: 40500 Avg. Training loss: 3.9002 0.0227 sec/batch
# Epoch 9/10 Iteration: 40600 Avg. Training loss: 3.8250 0.0227 sec/batch
# Epoch 9/10 Iteration: 40700 Avg. Training loss: 3.9539 0.0226 sec/batch
# Epoch 9/10 Iteration: 40800 Avg. Training loss: 3.9321 0.0226 sec/batch
# Epoch 9/10 Iteration: 40900 Avg. Training loss: 3.9406 0.0226 sec/batch
# Epoch 9/10 Iteration: 41000 Avg. Training loss: 3.8267 0.0226 sec/batch
# Nearest to his: he, career, lifetime, genius, had, himself, tragically, entered,
# Nearest to where: a, mandriva, in, tried, ruddy, be, indiscriminately, there,
# Nearest to to: in, the, and, with, for, s, on, that,
# Nearest to after: following, beholden, was, later, in, the, soon, on,
# Nearest to so: already, not, caddy, started, to, occupy, orthogonality, azo,
# Nearest to of: the, and, by, in, a, for, an, also,
# Nearest to that: an, be, a, to, this, in, the, and,
# Nearest to all: a, only, both, as, are, of, commemoration, significant,
# Nearest to discovered: discovery, dedekind, inhaled, hominin, landed, colony, disclosure, pauling,
# Nearest to placed: delphic, secures, remain, exclusively, recuperate, fractures, scientists, jackal,
# Nearest to hit: fang, johanson, atoll, cannae, hitting, being, peaked, penetrate,
# Nearest to arts: martial, academy, gendai, progenitors, tenured, practitioner, cashmere, hochschule,
# Nearest to cost: excel, atheism, attenuated, valo, crack, holstein, nodens, diarist,
# Nearest to professional: golfer, readiness, warhawk, brand, expressive, centennial, badminton, shocked,
# Nearest to freedom: freedoms, dissociate, liberalism, herd, leftists, equate, brezhnev, exploited,
# Nearest to smith: rothbard, opiate, degenerated, codex, modular, dontrelle, owl, asserts,
# Epoch 9/10 Iteration: 41100 Avg. Training loss: 3.7901 0.0232 sec/batch
# Epoch 9/10 Iteration: 41200 Avg. Training loss: 3.8888 0.0225 sec/batch
# Epoch 9/10 Iteration: 41300 Avg. Training loss: 3.7845 0.0227 sec/batch
# Epoch 9/10 Iteration: 41400 Avg. Training loss: 3.8749 0.0226 sec/batch
# Epoch 9/10 Iteration: 41500 Avg. Training loss: 3.8658 0.0226 sec/batch
# Epoch 9/10 Iteration: 41600 Avg. Training loss: 3.8556 0.0227 sec/batch
# Epoch 10/10 Iteration: 41700 Avg. Training loss: 3.9315 0.0110 sec/batch
# Epoch 10/10 Iteration: 41800 Avg. Training loss: 3.8137 0.0226 sec/batch
# Epoch 10/10 Iteration: 41900 Avg. Training loss: 3.8021 0.0227 sec/batch
# Epoch 10/10 Iteration: 42000 Avg. Training loss: 3.8427 0.0227 sec/batch
# Nearest to his: he, himself, had, genius, was, career, lifetime, wife,
# Nearest to where: in, a, tried, there, indiscriminately, tria, newcomers, at,
# Nearest to to: in, the, and, that, for, with, of, when,
# Nearest to after: following, beholden, later, was, in, crispus, the, soon,
# Nearest to so: already, not, to, occupy, started, caddy, galego, dicotyledonous,
# Nearest to of: the, and, by, a, in, for, is, an,
# Nearest to that: to, an, and, a, the, as, not, of,
# Nearest to all: a, both, only, as, of, are, commemoration, they,
# Nearest to discovered: discovery, inhaled, dedekind, hominin, landed, colony, disclosure, been,
# Nearest to placed: delphic, secures, scientists, remain, exclusively, fractures, jackal, posterity,
# Nearest to hit: johanson, fang, atoll, cannae, peaked, hitting, dickey, nefarious,
# Nearest to arts: martial, academy, gendai, progenitors, tenured, practitioner, cashmere, shaolin,
# Nearest to cost: excel, atheism, attenuated, cheaper, holstein, retain, lent, cuboctahedra,
# Nearest to professional: golfer, readiness, warhawk, expressive, brand, juniors, badminton, lacrosse,
# Nearest to freedom: freedoms, dissociate, liberalism, herd, equate, leftists, exploited, brezhnev,
# Nearest to smith: rothbard, modular, opiate, degenerated, owl, dontrelle, maxfield, codex,
# Epoch 10/10 Iteration: 42100 Avg. Training loss: 3.8229 0.0233 sec/batch
# Epoch 10/10 Iteration: 42200 Avg. Training loss: 3.7979 0.0226 sec/batch
# Epoch 10/10 Iteration: 42300 Avg. Training loss: 3.8491 0.0226 sec/batch
# Epoch 10/10 Iteration: 42400 Avg. Training loss: 3.7777 0.0225 sec/batch
# Epoch 10/10 Iteration: 42500 Avg. Training loss: 3.8227 0.0226 sec/batch
# Epoch 10/10 Iteration: 42600 Avg. Training loss: 3.8232 0.0226 sec/batch
# Epoch 10/10 Iteration: 42700 Avg. Training loss: 3.8619 0.0226 sec/batch
# Epoch 10/10 Iteration: 42800 Avg. Training loss: 3.7631 0.0226 sec/batch
# Epoch 10/10 Iteration: 42900 Avg. Training loss: 3.8213 0.0226 sec/batch
# Epoch 10/10 Iteration: 43000 Avg. Training loss: 3.7982 0.0226 sec/batch
# Nearest to his: he, career, himself, had, genius, lifetime, maesa, tragically,
# Nearest to where: a, in, be, are, an, is, there, at,
# Nearest to to: in, the, and, for, with, that, of, is,
# Nearest to after: following, was, beholden, later, crispus, galerius, from, in,
# Nearest to so: to, already, not, occupy, caddy, started, lathes, azo,
# Nearest to of: the, a, and, in, is, for, by, an,
# Nearest to that: to, an, a, is, as, be, in, the,
# Nearest to all: a, only, of, both, as, are, they, the,
# Nearest to discovered: discovery, inhaled, dedekind, hominin, landed, colony, lamiaceae, stringent,
# Nearest to placed: delphic, secures, scientists, fractures, exclusively, remain, recuperate, jackal,
# Nearest to hit: hitting, cannae, atoll, fang, johanson, dickey, penetrate, peaked,
# Nearest to arts: martial, academy, gendai, progenitors, tenured, practitioner, cashmere, shaolin,
# Nearest to cost: atheism, excel, attenuated, nodens, retain, cheaper, holstein, crack,
# Nearest to professional: readiness, golfer, badminton, expressive, warhawk, lacrosse, juniors, professionals,
# Nearest to freedom: freedoms, dissociate, herd, liberalism, leftists, exploited, equate, brezhnev,
# Nearest to smith: rothbard, opiate, owl, modular, dontrelle, codex, degenerated, maxfield,
# Epoch 10/10 Iteration: 43100 Avg. Training loss: 3.7638 0.0232 sec/batch
# Epoch 10/10 Iteration: 43200 Avg. Training loss: 3.8158 0.0226 sec/batch
# Epoch 10/10 Iteration: 43300 Avg. Training loss: 3.8342 0.0226 sec/batch
# Epoch 10/10 Iteration: 43400 Avg. Training loss: 3.8257 0.0225 sec/batch
# Epoch 10/10 Iteration: 43500 Avg. Training loss: 3.8325 0.0225 sec/batch
# Epoch 10/10 Iteration: 43600 Avg. Training loss: 3.8810 0.0226 sec/batch
# Epoch 10/10 Iteration: 43700 Avg. Training loss: 3.8590 0.0226 sec/batch
# Epoch 10/10 Iteration: 43800 Avg. Training loss: 3.8212 0.0226 sec/batch
# Epoch 10/10 Iteration: 43900 Avg. Training loss: 3.8106 0.0225 sec/batch
# Epoch 10/10 Iteration: 44000 Avg. Training loss: 3.8608 0.0226 sec/batch
# Nearest to his: he, career, himself, lifetime, genius, had, came, famed,
# Nearest to where: a, be, in, an, at, are, the, there,
# Nearest to to: the, in, and, for, with, of, s, that,
# Nearest to after: following, later, was, beholden, in, the, until, karnstein,
# Nearest to so: already, not, to, caddy, started, occupy, really, lathes,
# Nearest to of: the, and, a, is, in, by, for, an,
# Nearest to that: an, be, to, the, and, as, is, a,
# Nearest to all: a, of, both, only, are, as, the, they,
# Nearest to discovered: discovery, inhaled, dedekind, landed, hominin, discoverer, rainer, colony,
# Nearest to placed: delphic, secures, fractures, scientists, remain, exclusively, jackal, recuperate,
# Nearest to hit: fang, cannae, hitting, johanson, atoll, peaked, dickey, penetrate,
# Nearest to arts: martial, academy, progenitors, gendai, tenured, cashmere, practitioner, sonnets,
# Nearest to cost: atheism, excel, attenuated, nodens, holstein, retain, cheaper, oversized,
# Nearest to professional: golfer, readiness, expressive, warhawk, badminton, juniors, professionals, dominate,
# Nearest to freedom: freedoms, dissociate, liberalism, herd, leftists, free, brezhnev, foia,
# Nearest to smith: rothbard, dontrelle, degenerated, modular, opiate, codex, owl, maxfield,
# Epoch 10/10 Iteration: 44100 Avg. Training loss: 3.8768 0.0234 sec/batch
# Epoch 10/10 Iteration: 44200 Avg. Training loss: 3.8237 0.0225 sec/batch
# Epoch 10/10 Iteration: 44300 Avg. Training loss: 3.8230 0.0226 sec/batch
# Epoch 10/10 Iteration: 44400 Avg. Training loss: 3.8396 0.0226 sec/batch
# Epoch 10/10 Iteration: 44500 Avg. Training loss: 3.8882 0.0226 sec/batch
# Epoch 10/10 Iteration: 44600 Avg. Training loss: 3.8227 0.0227 sec/batch
# Epoch 10/10 Iteration: 44700 Avg. Training loss: 3.8006 0.0225 sec/batch
# Epoch 10/10 Iteration: 44800 Avg. Training loss: 3.8520 0.0226 sec/batch
# Epoch 10/10 Iteration: 44900 Avg. Training loss: 3.8325 0.0226 sec/batch
# Epoch 10/10 Iteration: 45000 Avg. Training loss: 3.8041 0.0225 sec/batch
# Nearest to his: he, career, genius, lifetime, himself, was, had, entered,
# Nearest to where: a, are, in, be, an, there, newcomers, indiscriminately,
# Nearest to to: the, in, and, for, with, of, s, on,
# Nearest to after: was, following, later, beholden, in, the, soon, moved,
# Nearest to so: not, already, to, occupy, started, caddy, are, really,
# Nearest to of: the, and, a, by, in, is, for, an,
# Nearest to that: an, be, the, and, a, to, as, by,
# Nearest to all: a, of, only, both, are, as, lives, not,
# Nearest to discovered: discovery, inhaled, dedekind, landed, hominin, had, discoverer, colony,
# Nearest to placed: delphic, secures, remain, scientists, recuperate, jackal, fractures, exclusively,
# Nearest to hit: fang, hitting, atoll, cannae, johanson, penetrate, dickey, peaked,
# Nearest to arts: martial, academy, progenitors, gendai, tenured, cashmere, hochschule, insignia,
# Nearest to cost: excel, atheism, attenuated, holstein, cheaper, retain, nodens, oversized,
# Nearest to professional: readiness, golfer, expressive, warhawk, badminton, professionals, dominate, lacrosse,
# Nearest to freedom: freedoms, dissociate, herd, leftists, liberalism, exploited, brezhnev, equate,
# Nearest to smith: rothbard, modular, codex, opiate, degenerated, maxfield, canning, dontrelle,
# Epoch 10/10 Iteration: 45100 Avg. Training loss: 3.8462 0.0233 sec/batch
# Epoch 10/10 Iteration: 45200 Avg. Training loss: 3.8265 0.0227 sec/batch
# Epoch 10/10 Iteration: 45300 Avg. Training loss: 3.9235 0.0227 sec/batch
# Epoch 10/10 Iteration: 45400 Avg. Training loss: 3.9105 0.0226 sec/batch
# Epoch 10/10 Iteration: 45500 Avg. Training loss: 3.8841 0.0226 sec/batch
# Epoch 10/10 Iteration: 45600 Avg. Training loss: 3.8416 0.0226 sec/batch
# Epoch 10/10 Iteration: 45700 Avg. Training loss: 3.7907 0.0225 sec/batch
# Epoch 10/10 Iteration: 45800 Avg. Training loss: 3.8415 0.0225 sec/batch
# Epoch 10/10 Iteration: 45900 Avg. Training loss: 3.7457 0.0226 sec/batch
# Epoch 10/10 Iteration: 46000 Avg. Training loss: 3.8872 0.0226 sec/batch
# Nearest to his: he, career, had, genius, himself, lifetime, schooling, graduated,
# Nearest to where: a, be, an, mandriva, in, indiscriminately, are, there,
# Nearest to to: in, the, and, with, for, s, of, that,
# Nearest to after: later, beholden, was, following, s, before, began, in,
# Nearest to so: not, already, to, caddy, occupy, are, lathes, started,
# Nearest to of: the, a, and, in, by, is, for, also,
# Nearest to that: an, be, the, a, to, not, say, as,
# Nearest to all: a, only, both, of, are, lives, as, commemoration,
# Nearest to discovered: discovery, inhaled, dedekind, landed, hominin, had, colony, disclosure,
# Nearest to placed: secures, delphic, scientists, fractures, recuperate, remain, e, exclusively,
# Nearest to hit: fang, atoll, johanson, cannae, penetrate, peaked, being, hitting,
# Nearest to arts: martial, gendai, academy, progenitors, practitioner, muay, shaolin, cashmere,
# Nearest to cost: excel, atheism, attenuated, cheaper, retain, holstein, benefices, oversized,
# Nearest to professional: readiness, golfer, warhawk, expressive, wrestler, badminton, brand, characterized,
# Nearest to freedom: freedoms, dissociate, herd, liberalism, leftists, exploited, equate, promotes,
# Nearest to smith: rothbard, opiate, dontrelle, codex, yakima, degenerated, canning, maxfield,
# Epoch 10/10 Iteration: 46100 Avg. Training loss: 3.8431 0.0233 sec/batch
# Epoch 10/10 Iteration: 46200 Avg. Training loss: 3.8240 0.0226 sec/batch

# %% [markdown]
# Restore the trained network if you need to:

# %%
with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    embed_mat = sess.run(embedding)
# Out:
# INFO:tensorflow:Restoring parameters from checkpoints/text8.ckpt

# %% [markdown]
# ## Visualizing the word vectors
#
# Below we'll use T-SNE to visualize how our high-dimensional word vectors cluster together. T-SNE is used to project these vectors into two dimensions while preserving local stucture. Check out [this post from Christopher Olah](http://colah.github.io/posts/2014-10-Visualizing-MNIST/) to learn more about T-SNE and other ways to visualize high-dimensional data.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# %%
viz_words = 500
tsne = TSNE()
embed_tsne = tsne.fit_transform(embed_mat[:viz_words, :])

# %%
fig, ax = plt.subplots(figsize=(14, 14))
for idx in range(viz_words):
    plt.scatter(*embed_tsne[idx, :], color='steelblue')
    plt.annotate(int_to_vocab[idx], (embed_tsne[idx, 0], embed_tsne[idx, 1]), alpha=0.7)
